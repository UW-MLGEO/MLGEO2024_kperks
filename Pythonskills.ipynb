# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
list1 = ['a',2,True]
print(list1)
# Out:
# ['a', 2, True]

# %%
array1 = np.array([[1,2],[3,4]])
print(array1)
# Out:
# [[1 2]
#  [3 4]]

# %%
def f1(x):
    return (1+x)/5

# %%
f1(2)
# Out:
# 0.6

# %%
x= np.linspace(1,5)
plt.plot(x,f1(x))
plt.xlabel('Numbers')
plt.ylabel('Function')
plt.title('myPlot')
# Out:
# Text(0.5, 1.0, 'myPlot')

# %%
plt.savefig('myplot.png')
